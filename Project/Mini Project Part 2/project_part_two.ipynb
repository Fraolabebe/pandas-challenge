# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
coders_df=pd.read_csv(file)
coders_df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                    NaN                NaN          NaN                 NaN
# 1                    NaN                NaN          NaN                 NaN
# 2                    NaN                NaN          NaN                 NaN
# 3                    NaN                NaN          NaN                 NaN
# 4                    NaN                NaN          NaN                 NaN
# ...                  ...                ...          ...                 ...
# 15615                NaN                NaN          NaN                 NaN
# 15616                NaN                NaN          NaN                 NaN
# 15617                NaN                NaN          NaN                 NaN
# 15618                NaN                NaN          NaN                 NaN
# 15619                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                    NaN             NaN  ...               NaN
# 1                    NaN             NaN  ...               NaN
# 2                    NaN             NaN  ...               NaN
# 3                    NaN             NaN  ...               NaN
# 4                    NaN             NaN  ...               NaN
# ...                  ...             ...  ...               ...
# 15615                NaN             NaN  ...               NaN
# 15616                NaN             NaN  ...               NaN
# 15617                NaN             NaN  ...               NaN
# 15618                NaN             NaN  ...               NaN
# 15619                NaN             NaN  ...               NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
# ...                      ...                ...              ...
# 15615                    NaN                NaN              NaN
# 15616                    NaN                1.0              NaN
# 15617                    NaN                NaN              NaN
# 15618                    NaN                NaN              NaN
# 15619                    NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 0                NaN                NaN              NaN
# 1                1.0                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN
# ...              ...                ...              ...
# 15615            1.0                NaN              NaN
# 15616            NaN                NaN              NaN
# 15617            NaN                NaN              NaN
# 15618            1.0                NaN              NaN
# 15619            NaN                NaN              NaN
#
#                                   SchoolDegree              SchoolMajor  \
# 0               some college credit, no degree                      NaN
# 1               some college credit, no degree                      NaN
# 2      high school diploma or equivalent (GED)                      NaN
# 3                            bachelor's degree  Cinematography And Film
# 4               some college credit, no degree                      NaN
# ...                                        ...                      ...
# 15615                        bachelor's degree                Chemistry
# 15616                        bachelor's degree   Electrical Engineering
# 15617                        bachelor's degree                Chemistry
# 15618       master's degree (non-professional)                     Math
# 15619                        bachelor's degree           Graphic Design
#
#        StudentDebtOwe
# 0             20000.0
# 1                 NaN
# 2                 NaN
# 3              7000.0
# 4                 NaN
# ...               ...
# 15615             NaN
# 15616             NaN
# 15617             NaN
# 15618             NaN
# 15619         40000.0
#
# [15620 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
Extracted_coders_df= coders_df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
Extracted_coders_df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  \
# 0                    NaN                 NaN                NaN
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
# ...                  ...                 ...                ...
# 15615                NaN                 NaN                NaN
# 15616                NaN                 NaN                NaN
# 15617                NaN                 NaN                NaN
# 15618                NaN                 NaN                NaN
# 15619                NaN                 NaN                NaN
#
#        ChildrenNumber                 CityPopulation  CodeEventBootcamp  \
# 0                 NaN  between 100,000 and 1 million                NaN
# 1                 NaN  between 100,000 and 1 million                NaN
# 2                 NaN            more than 1 million                NaN
# 3                 NaN            more than 1 million                NaN
# 4                 NaN  between 100,000 and 1 million                NaN
# ...               ...                            ...                ...
# 15615             NaN            more than 1 million                NaN
# 15616             NaN            more than 1 million                NaN
# 15617             NaN            more than 1 million                NaN
# 15618             NaN            more than 1 million                NaN
# 15619             NaN            more than 1 million                NaN
#
#                     CountryLive                        EmploymentField  \
# 0      United States of America      office and administrative support
# 1      United States of America                      food and beverage
# 2      United States of America                                finance
# 3      United States of America  arts, entertainment, sports, or media
# 4      United States of America                              education
# ...                         ...                                    ...
# 15615                     Kenya            software development and IT
# 15616                     India            software development and IT
# 15617                   Nigeria                                    NaN
# 15618                     Spain                              education
# 15619  United States of America  arts, entertainment, sports, or media
#
#                EmploymentStatus  Gender  HasChildren  HoursLearning   Income  \
# 0            Employed for wages    male          0.0           30.0  32000.0
# 1            Employed for wages    male          NaN           30.0  15000.0
# 2            Employed for wages    male          NaN           20.0  48000.0
# 3            Employed for wages  female          NaN           20.0  43000.0
# 4            Employed for wages  female          NaN           25.0   6000.0
# ...                         ...     ...          ...            ...      ...
# 15615  Self-employed freelancer    male          0.0           40.0  10000.0
# 15616        Employed for wages    male          0.0           15.0  10000.0
# 15617  Self-employed freelancer    male          NaN           14.0  48000.0
# 15618  Self-employed freelancer    male          NaN           10.0  10000.0
# 15619        Employed for wages  female          0.0            2.0  18000.0
#
#                  JobRoleInterest                             SchoolDegree  \
# 0                            NaN           some college credit, no degree
# 1        Front-End Web Developer           some college credit, no degree
# 2                            NaN  high school diploma or equivalent (GED)
# 3        Front-End Web Developer                        bachelor's degree
# 4       Full-Stack Web Developer           some college credit, no degree
# ...                          ...                                      ...
# 15615                        NaN                        bachelor's degree
# 15616    Front-End Web Developer                        bachelor's degree
# 15617                        NaN                        bachelor's degree
# 15618                        NaN       master's degree (non-professional)
# 15619                        NaN                        bachelor's degree
#
#                    SchoolMajor
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3      Cinematography And Film
# 4                          NaN
# ...                        ...
# 15615                Chemistry
# 15616   Electrical Engineering
# 15617                Chemistry
# 15618                     Math
# 15619           Graphic Design
#
# [15620 rows x 20 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
coders_df["AttendedBootcamp"] = coders_df["AttendedBootcamp"].replace({0: "No", 1: "Yes"})
coders_df["AttendedBootcamp"].value_counts()
# Out:
# No     14427
# Yes      953
# Name: AttendedBootcamp, dtype: int64

# %%
# Extract rows for only those who attended a bootcamp
attended_bootcamp = Extracted_coders_df.loc[Extracted_coders_df['AttendedBootcamp'] == "Yes"]
attended_bootcamp.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                 No                 NaN                No            NaN
# 97                 No             45000.0                No            NaN
# 130               Yes             75000.0               Yes              3
# 159                No                 NaN                No            NaN
# 188               Yes                 NaN                No            NaN
#
#                     CityPopulation CodeEventBootcamp  \
# 93   between 100,000 and 1 million               NaN
# 97             more than 1 million               NaN
# 130              less than 100,000               NaN
# 159  between 100,000 and 1 million               NaN
# 188  between 100,000 and 1 million               NaN
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender HasChildren HoursLearning  \
# 93           Self-employed business owner    male         NaN            20
# 97                     Employed for wages    male          No            10
# 130                    Employed for wages    male         Yes            30
# 159  Not working and not looking for work  female         NaN            30
# 188      Not working but looking for work  female         NaN            60
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN

# %%
attended_bootcamp_count = attended_bootcamp["BootcampName"].value_counts().count()
attended_bootcamp_count = attended_bootcamp["BootcampName"].value_counts().loc[lambda x : x>25].count()

print(f"Significant Bootcamps")
print(f"------------------------------------\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BootcampName'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-22cb2792dc98> in <module>
# ----> 1 attended_bootcamp_count = attended_bootcamp["BootcampName"].value_counts().count()
#       2 attended_bootcamp_count = attended_bootcamp["BootcampName"].value_counts().loc[lambda x : x>25].count()
#       3
#       4 print(f"Significant Bootcamps")
#       5 print(f"------------------------------------\n")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BootcampName'

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
Bootcampnames_df = coders_df.groupby(["BootcampName"])
print(Bootcampnames_df)
NewBootcamp_df = Bootcampnames_df.count().sort_values("AttendedBootcamp", ascending=False).head()
NewBootcamp_df = NewBootcamp_df[["AttendedBootcamp"]].head()
NewBootcamp_df
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f9f1dad5cd0>
#                        AttendedBootcamp
# BootcampName
# General Assembly                     90
# Flatiron School                      54
# Dev Bootcamp                         48
# The Iron Yard                        40
# Prime Digital Academy                30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp

recommend_bootcamp =NewBootcamp_df.groupby(["BootcampName"]).count()
sign_bootcamp_group 
recommend_bootcamp_df = pd.DataFrame(recommend_bootcamp)
recommend_bootcamp_df
# Out:
#                        AttendedBootcamp
# BootcampName
# Dev Bootcamp                          1
# Flatiron School                       1
# General Assembly                      1
# Prime Digital Academy                 1
# The Iron Yard                         1

# %%
# Merge the two created data frames on the name of tbe bootcamp
recommend_bootcamp = pd.DataFrame(recommend_bootcamp.groupby(["BootcampName"]).count()
highly_recommend_bootcamp = recommend_bootcamp["BootcampRecomment"]
# Out:
#   File "<ipython-input-45-4c678714665d>", line 3
#     highly_recommend_bootcamp = recommend_bootcamp["BootcampRecomment"]
#     ^
# SyntaxError: invalid syntax

# %%
highly_recommend_bootcamp = recommend_bootcamp["BootcampRecomment"]

# %%
# Calculate percentage of eac bootcamp's students who are recommenders

# %%
# Export to excel and remove index
